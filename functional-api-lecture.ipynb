# %% [markdown]
# # More Complex Models with the Functional API
#
# Although the Sequential API in Keras is quite straightforward and Sequential models are quite common, it is sometime useful to build networks with more complex topologies, or multiple inputs or outputs. The Keras Functional API provides a more flexible way to define models that makes this possible. It is particularly useful for models with non-linear topology, shared layers, or multiple inputs/outputs.
#
# In this lecture, we'll delve into the Functional API with a focus on building a ["Wide & Deep" network](https://ai.google/research/pubs/pub45413), a model architecture that can manage both deep and wide feature learning effectively.
#
# #### When to Use the Functional API
#
# - **Model Complexity:** The Functional API is ideal when dealing with complex model architectures, such as those requiring multiple input and output layers, shared layers, or residual connections.
# - **Flexibility:** It allows for more customization and control over your model architecture. Unlike the Sequential API, where layers are stacked linearly, the Functional API enables you to define more complex and non-linear relationships.
# - **Research and Experimentation:** If you're experimenting with novel architectures or conducting research, the Functional API allows for more experimental flexibility.
#
# ## Designing a Wide & Deep Network for More Complex Data
#
# The "Wide & Deep" learning model, conceptualized by Google, is designed to effectively harness both linear and non-linear feature representations. Understanding why and how this model works involves delving into the strengths of its two components: the "wide" part for linear aspects and the "deep" part for complex relationships.
#
# <div style="text-align:center">
#
# ![wide and deep nn](assets/wide_and_deep.png)
#
# </div>
#
# #### The "Wide" Component
#
# - **Linear Relationships:**
#   - The wide part of the model is designed to learn linear relationships. This means it's good at memorizing or managing sparse data and feature interactions.
#   - In practice, this often translates to a form of logistic regression or linear regression, depending on the task.
#
# - **Feature Interactions:**
#   - The wide component can effectively capture simple rules and interactions between features. For instance, if certain feature combinations are particularly predictive of the target variable, the wide component can learn this directly.
#
# - **Advantage in Memorization:**
#   - The wide part excels in memorization, which is beneficial for learning from sparse data where certain feature combinations may be very predictive but don't occur frequently enough for a deep model to learn and generalize. Categorical features, especially those with a large number of possible values, often work well with the wide part.
#
# #### The "Deep" Component
#
# - **Complex Relationships:**
#   - The deep component, typically a deep neural network, is adept at learning complex, non-linear relationships and feature hierarchies.
#   - These networks automatically learn to represent data in a hierarchical fashion (low-level features in early layers, more abstract features in deeper layers).
#
# - **Generalization:**
#   - Deep networks are particularly good at generalizing to new scenarios. They can infer unseen relationships based on the hierarchies they've learned, making them powerful for tasks involving unstructured data like images and text.
#
# - **Feature Learning:**
#   - Unlike the wide part, deep networks don't require explicit feature engineering. They can automatically learn useful representations from raw data, making them highly versatile and adaptable. Numerical features, particularly those that require complex transformations to relate to the output, are suitable for the deep part.
#
#
# The Wide & Deep model combines the strengths of memorization and generalization. Use the wide part for features where the relationship with the output is expected to be linear or rule-based, and the deep part for more abstract patterns and relationships. For example, in a recommendation system, the wide part can effectively capture specific user-item interactions (like a particular user's preference for a specific genre), while the deep part can learn user preferences and item characteristics from user and item metadata.
#
# When designing a Wide & Deep model, balance is key. Overemphasizing the wide part might lead to overfitting on specific feature combinations, while focusing too much on the deep part might result in missing out on simple, predictive rules in the data. The optimal balance often depends on the specific nature of the dataset and the problem.
#
# ## Implementing a Wide & Deep Network
#
# We'll develop a Wide & Deep Network to tackle the [California Housing dataset](https://developers.google.com/machine-learning/crash-course/california-housing-data-description). The dataset includes a mix of features, some of which have a clear linear relationship with the target variable, while others may have more complex, non-linear relationships.  For example, features like 'median income' might have a more straightforward, linear relationship with housing prices. In contrast, features like 'latitude' and 'longitude' could have a non-linear and more complex interaction with the price.
#
# Our goal here is to predict the median house price for each "block group."
#
# #### Retrieving the data

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow)
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.5.4-py3-none-any.whl (19 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 1.5 MB/s eta 0:00:00
# Collecting h5py>=2.9.0 (from tensorflow)
#   Downloading h5py-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting ml-dtypes~=0.2.0 (from tensorflow)
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (1.26.1)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (23.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow)
#   Downloading protobuf-4.25.1-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in /usr/local/python/3.10.8/lib/python3.10/site-packages (from tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (4.8.0)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 2.5 MB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.34.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (14 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.59.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow)
#   Downloading tensorboard-2.15.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Downloading wheel-0.42.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.16,>=2.15->tensorflow)
#   Downloading google_auth-2.23.4-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<2,>=0.5 (from tensorboard<2.16,>=2.15->tensorflow)
#   Downloading google_auth_oauthlib-1.1.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.16,>=2.15->tensorflow)
#   Downloading Markdown-3.5.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow)
#   Downloading protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl.metadata (540 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/codespace/.local/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.16,>=2.15->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.16,>=2.15->tensorflow)
#   Downloading werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow)
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow)
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 5.3 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow)
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.3)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow)
#   Downloading pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow)
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 4.4 MB/s eta 0:00:00
# Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 3.0 MB/s eta 0:00:00:00:0100:01
# Downloading absl_py-2.0.0-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 3.6 MB/s eta 0:00:00
# Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Downloading grpcio-1.59.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 46.3 MB/s eta 0:00:00:00:0100:01
# Downloading h5py-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 45.4 MB/s eta 0:00:00:00:01
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 29.5 MB/s eta 0:00:00:00:01
# Downloading libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl (22.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.9/22.9 MB 36.5 MB/s eta 0:00:00:00:0100:01
# Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 22.1 MB/s eta 0:00:00:00:01
# Downloading tensorboard-2.15.1-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 50.8 MB/s eta 0:00:00:00:0100:01
# Downloading protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 7.2 MB/s eta 0:00:00:00:01
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 9.9 MB/s eta 0:00:00:00:01
# Downloading tensorflow_io_gcs_filesystem-0.34.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 36.2 MB/s eta 0:00:00:00:01
# Downloading google_auth-2.23.4-py2.py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.3/183.3 kB 5.9 MB/s eta 0:00:00
# Downloading google_auth_oauthlib-1.1.0-py2.py3-none-any.whl (19 kB)
# Downloading Markdown-3.5.1-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 3.2 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 53.1 MB/s eta 0:00:00:00:0100:01
# Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 6.9 MB/s eta 0:00:00
# Downloading wheel-0.42.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 1.8 MB/s eta 0:00:00
# Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: libclang, flatbuffers, wrapt, wheel, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, pyasn1, protobuf, opt-einsum, oauthlib, ml-dtypes, markdown, keras, h5py, grpcio, google-pasta, gast, cachetools, absl-py, rsa, requests-oauthlib, pyasn1-modules, astunparse, google-auth, google-auth-oauthlib, tensorboard, tensorflow
# Successfully installed absl-py-2.0.0 astunparse-1.6.3 cachetools-5.3.2 flatbuffers-23.5.26 gast-0.5.4 google-auth-2.23.4 google-auth-oauthlib-1.1.0 google-pasta-0.2.0 grpcio-1.59.3 h5py-3.10.0 keras-2.15.0 libclang-16.0.6 markdown-3.5.1 ml-dtypes-0.2.0 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-4.23.4 pyasn1-0.5.1 pyasn1-modules-0.3.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.15.1 tensorboard-data-server-0.7.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 tensorflow-io-gcs-filesystem-0.34.0 termcolor-2.3.0 werkzeug-3.0.1 wheel-0.42.0 wrapt-1.14.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
# Out:
# 2023-11-27 19:47:17.830571: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-27 19:47:17.862908: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-27 19:47:17.862942: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-27 19:47:17.864227: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-27 19:47:17.870118: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-27 19:47:17.870982: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-27 19:47:18.881315: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
housing = fetch_california_housing()
X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, random_state=42)
# Reserve an item for prediction
X_new = X_test[:3]

# %%
print(housing.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block group
#         - HouseAge      median house age in block group
#         - AveRooms      average number of rooms per household
#         - AveBedrms     average number of bedrooms per household
#         - Population    block group population
#         - AveOccup      average number of household members
#         - Latitude      block group latitude
#         - Longitude     block group longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# A household is a group of people residing within a home. Since the average
# number of rooms and bedrooms in this dataset are provided per household, these
# columns may take surprisingly large values for block groups with few households
# and many empty houses, such as vacation resorts.
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297

# %%
import numpy as np
# Note that outputs are in $100,000
print(f"Min {np.min(y_train_full)} - Max {np.max(y_train_full)}")
# Out:
# Min 0.14999 - Max 5.00001

# %% [markdown]
# #### Setting up the model

# %%
# extra code – reset the name counters and make the code reproducible
tf.keras.backend.clear_session()
tf.random.set_seed(42)

# Normalization layer to standardize the inputs,, , and one more Dense layer with a single neuron for the output layer, without any activation function
normalization_layer = tf.keras.layers.Normalization()

# two Dense layers with 30 neurons each, using the ReLU activation function
hidden_layer1 = tf.keras.layers.Dense(30, activation="relu")
hidden_layer2 = tf.keras.layers.Dense(30, activation="relu")

#Concatenate layer - In a Wide & Deep network, you have two paths: the wide path (simple linear relationships) 
#and the deep path (complex non-linear relationships). The concatenate layer is used to merge these two paths. 
#It takes outputs from both the wide and deep components and concatenates them along a specified axis (by default, the last axis).
concat_layer = tf.keras.layers.Concatenate()

#Dense layer with a single neuron for the output layer, without any activation function.  This is the median housing price.
output_layer = tf.keras.layers.Dense(1)

# The Input object (the variable name input_ is used to avoid overshadowing Python’s built-in input() function). 
# This is a specification of the kind of input the model 
# will get, including its shape and optionally its dtype, which defaults to 32-bit floats. 
# A model may actually have multiple inputs, as you will see shortly.
input_ = tf.keras.layers.Input(shape=X_train.shape[1:])


#Normalization layer just like a function, passing it the Input object. This is why this is called the functional API. 
# Note that we are just telling Keras how it should connect the layers together; no actual data is being processed yet, 
# as the Input object is just a data specification. In other words, it’s a symbolic input. The output of this call is 
# also symbolic: normalized doesn’t store any actual data, it’s just used to construct the model.
normalized = normalization_layer(input_)

# In the same way, we then pass normalized to hidden_layer1, which outputs hidden1, 
# and we pass hidden1 to hidden_layer2, which outputs hidden2.
hidden1 = hidden_layer1(normalized)
hidden2 = hidden_layer2(hidden1)

#So far we’ve connected the layers sequentially, but then we use the concat_layer to 
# concatenate the input and the second hidden layer’s output. Again, no actual data is 
# concatenated yet: it’s all symbolic, to build the model.
concat = concat_layer([normalized, hidden2])

# Then we pass concat to the output_layer, which gives us the final output.
output = output_layer(concat)

# Finally create the model, specifying inputs and outputs
model = tf.keras.Model(inputs=[input_], outputs=[output])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 8)]                  0         []
#
#  normalization (Normalizati  (None, 8)                    17        ['input_1[0][0]']
#  on)
#
#  dense (Dense)               (None, 30)                   270       ['normalization[0][0]']
#
#  dense_1 (Dense)             (None, 30)                   930       ['dense[0][0]']
#
#  concatenate (Concatenate)   (None, 38)                   0         ['normalization[0][0]',
#                                                                      'dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    39        ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 1256 (4.91 KB)
# Trainable params: 1239 (4.84 KB)
# Non-trainable params: 17 (72.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# Once again, we compile and train the model, just like before...

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="mse", optimizer=optimizer, metrics=["RootMeanSquaredError"])

# This is necessary in order to make sure the normalization layer correctly calculate things like the mean and 
# standard deviation necessary
normalization_layer.adapt(X_train)
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
mse_test = model.evaluate(X_test, y_test)
y_pred = model.predict(X_new)
# Out:
# Epoch 1/20
# 363/363 [==============================] - 1s 2ms/step - loss: 1.2061 - root_mean_squared_error: 1.0982 - val_loss: 0.5366 - val_root_mean_squared_error: 0.7325
# Epoch 2/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4554 - root_mean_squared_error: 0.6749 - val_loss: 0.4518 - val_root_mean_squared_error: 0.6722
# Epoch 3/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3969 - root_mean_squared_error: 0.6300 - val_loss: 0.3974 - val_root_mean_squared_error: 0.6304
# Epoch 4/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3780 - root_mean_squared_error: 0.6148 - val_loss: 0.8086 - val_root_mean_squared_error: 0.8992
# Epoch 5/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3632 - root_mean_squared_error: 0.6026 - val_loss: 0.7207 - val_root_mean_squared_error: 0.8490
# Epoch 6/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3551 - root_mean_squared_error: 0.5959 - val_loss: 1.9861 - val_root_mean_squared_error: 1.4093
# Epoch 7/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3610 - root_mean_squared_error: 0.6008 - val_loss: 1.5131 - val_root_mean_squared_error: 1.2301
# Epoch 8/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3398 - root_mean_squared_error: 0.5829 - val_loss: 5.9008 - val_root_mean_squared_error: 2.4292
# Epoch 9/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3499 - root_mean_squared_error: 0.5915 - val_loss: 2.6561 - val_root_mean_squared_error: 1.6297
# Epoch 10/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3459 - root_mean_squared_error: 0.5881 - val_loss: 0.7815 - val_root_mean_squared_error: 0.8840
# Epoch 11/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3200 - root_mean_squared_error: 0.5657 - val_loss: 0.3060 - val_root_mean_squared_error: 0.5531
# Epoch 12/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3169 - root_mean_squared_error: 0.5629 - val_loss: 0.4620 - val_root_mean_squared_error: 0.6797
# Epoch 13/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3121 - root_mean_squared_error: 0.5587 - val_loss: 0.3037 - val_root_mean_squared_error: 0.5511
# Epoch 14/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3092 - root_mean_squared_error: 0.5560 - val_loss: 0.3396 - val_root_mean_squared_error: 0.5827
# Epoch 15/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3082 - root_mean_squared_error: 0.5552 - val_loss: 0.3144 - val_root_mean_squared_error: 0.5607
# Epoch 16/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3045 - root_mean_squared_error: 0.5518 - val_loss: 0.3385 - val_root_mean_squared_error: 0.5818
# Epoch 17/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3031 - root_mean_squared_error: 0.5505 - val_loss: 0.3022 - val_root_mean_squared_error: 0.5497
# Epoch 18/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.2994 - root_mean_squared_error: 0.5472 - val_loss: 0.7482 - val_root_mean_squared_error: 0.8650
# Epoch 19/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.2998 - root_mean_squared_error: 0.5476 - val_loss: 0.6318 - val_root_mean_squared_error: 0.7949
# Epoch 20/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3055 - root_mean_squared_error: 0.5527 - val_loss: 1.6134 - val_root_mean_squared_error: 1.2702
# 162/162 [==============================] - 0s 864us/step - loss: 0.3109 - root_mean_squared_error: 0.5576
# 1/1 [==============================] - 0s 58ms/step

# %%
import matplotlib.pyplot as plt
import pandas as pd

pd.DataFrame(history.history).plot(
    figsize=(8, 5), xlim=[0, 20], ylim=[0, 2], grid=True, xlabel="Epoch",
    style=["r--", "r--.", "b-", "b-*"])
plt.legend(loc="lower left")  # extra code
plt.show()

# %% [markdown]
# Yikes!  Note that an RMS error of 1 (roughly our mean validation error) is $100,000, which isn't great.
#
# There are a few things we might try.  First, we might consider splitting our features, so that the "wide" and "deep" part of the network focus on different subsets of features.  For example, we might send the first five features through the wide path (based on the assumption that these should have a linear relationship with price) and the last six features through the deep path (assuming a more complex relationship here). Note that this is how we can use our domain knowledge to construct a network!
#
# The envisioned network looks something like:
#
# <div style="text-align:center">
#
# ![Wide and deep 2](assets/wide_and_deep2.png)
#
# </div>

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)

input_wide = tf.keras.layers.Input(shape=[5]) # features 0 to 4 
input_deep = tf.keras.layers.Input(shape=[6]) # features 2 to 7 
norm_layer_wide = tf.keras.layers.Normalization() 
norm_layer_deep = tf.keras.layers.Normalization()
norm_wide = norm_layer_wide(input_wide)
norm_deep = norm_layer_deep(input_deep)

# Note, the following is just a shorthand where we construct and then attach the network all in one go
hidden1 = tf.keras.layers.Dense(30, activation="relu")(norm_deep)
hidden2 = tf.keras.layers.Dense(30, activation="relu")(hidden1)
concat = tf.keras.layers.concatenate([norm_wide, hidden2])
output = tf.keras.layers.Dense(1)(concat)
model = tf.keras.Model(inputs=[input_wide, input_deep], outputs=[output])

# %% [markdown]
# Now we compile as usual, but we need to pass a pair of matrices in order to align with the expected input, and similarly with the validation and test data.

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="mse", optimizer=optimizer, metrics=["RootMeanSquaredError"])

# Note the offsets are used here to split up the features according to our input layer
X_train_wide, X_train_deep = X_train[:, :5], X_train[:, 2:] 
X_valid_wide, X_valid_deep = X_valid[:, :5], X_valid[:, 2:] 
X_test_wide, X_test_deep = X_test[:, :5], X_test[:, 2:] 
X_new_wide, X_new_deep = X_test_wide[:3], X_test_deep[:3]


norm_layer_wide.adapt(X_train_wide) 
norm_layer_deep.adapt(X_train_deep)

history = model.fit((X_train_wide, X_train_deep), y_train, epochs=20, validation_data=((X_valid_wide, X_valid_deep), y_valid)) 
mse_test = model.evaluate((X_test_wide, X_test_deep), y_test)
y_pred = model.predict((X_new_wide, X_new_deep))
# Out:
# Epoch 1/20
# 363/363 [==============================] - 1s 2ms/step - loss: 1.1366 - root_mean_squared_error: 1.0661 - val_loss: 0.6050 - val_root_mean_squared_error: 0.7778
# Epoch 2/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4937 - root_mean_squared_error: 0.7026 - val_loss: 0.6858 - val_root_mean_squared_error: 0.8281
# Epoch 3/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.4338 - root_mean_squared_error: 0.6586 - val_loss: 0.3962 - val_root_mean_squared_error: 0.6295
# Epoch 4/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4092 - root_mean_squared_error: 0.6397 - val_loss: 0.4724 - val_root_mean_squared_error: 0.6873
# Epoch 5/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3953 - root_mean_squared_error: 0.6288 - val_loss: 0.3614 - val_root_mean_squared_error: 0.6011
# Epoch 6/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3823 - root_mean_squared_error: 0.6183 - val_loss: 0.4941 - val_root_mean_squared_error: 0.7029
# Epoch 7/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3785 - root_mean_squared_error: 0.6152 - val_loss: 0.5904 - val_root_mean_squared_error: 0.7684
# Epoch 8/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3691 - root_mean_squared_error: 0.6075 - val_loss: 1.8021 - val_root_mean_squared_error: 1.3424
# Epoch 9/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3674 - root_mean_squared_error: 0.6061 - val_loss: 2.9847 - val_root_mean_squared_error: 1.7276
# Epoch 10/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3799 - root_mean_squared_error: 0.6163 - val_loss: 0.7859 - val_root_mean_squared_error: 0.8865
# Epoch 11/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3585 - root_mean_squared_error: 0.5988 - val_loss: 0.5513 - val_root_mean_squared_error: 0.7425
# Epoch 12/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3561 - root_mean_squared_error: 0.5967 - val_loss: 0.4825 - val_root_mean_squared_error: 0.6946
# Epoch 13/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3489 - root_mean_squared_error: 0.5907 - val_loss: 0.6608 - val_root_mean_squared_error: 0.8129
# Epoch 14/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3499 - root_mean_squared_error: 0.5915 - val_loss: 0.8617 - val_root_mean_squared_error: 0.9283
# Epoch 15/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3482 - root_mean_squared_error: 0.5901 - val_loss: 1.3480 - val_root_mean_squared_error: 1.1611
# Epoch 16/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3461 - root_mean_squared_error: 0.5883 - val_loss: 0.8745 - val_root_mean_squared_error: 0.9351
# Epoch 17/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3438 - root_mean_squared_error: 0.5864 - val_loss: 0.7550 - val_root_mean_squared_error: 0.8689
# Epoch 18/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3361 - root_mean_squared_error: 0.5798 - val_loss: 0.3199 - val_root_mean_squared_error: 0.5656
# Epoch 19/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3320 - root_mean_squared_error: 0.5762 - val_loss: 0.4273 - val_root_mean_squared_error: 0.6537
# Epoch 20/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3364 - root_mean_squared_error: 0.5800 - val_loss: 0.3097 - val_root_mean_squared_error: 0.5565
# 162/162 [==============================] - 0s 962us/step - loss: 0.3279 - root_mean_squared_error: 0.5726
# 1/1 [==============================] - 0s 44ms/step

# %%
import matplotlib.pyplot as plt
import pandas as pd

pd.DataFrame(history.history).plot(
    figsize=(8, 5), xlim=[0, 20], ylim=[0, 2], grid=True, xlabel="Epoch",
    style=["r--", "r--.", "b-", "b-*"])
plt.legend(loc="lower left")  # extra code
plt.show()

# %% [markdown]
# Yikes! Another thing we can try here is to give the hidden layers an explicit training signal in order to force them to learn something directly about the data.  This is a type of regularization, because it helps to constrain the hidden layers so that they are not simply "memorizing" the data.  Our new architecture would look something like:
#
# <div style="text-align: center">
#
# ![Wide and deep 3](assets/wide_and_deep3.png)
#
# </div>
#
# Our auxiliary output requires is own loss function, but these two losses are combined during training.  Keras allows us to specify a weighting that will allow us to control the relative importance of these two losses.

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)

input_wide = tf.keras.layers.Input(shape=[5])  # features 0 to 4
input_deep = tf.keras.layers.Input(shape=[6])  # features 2 to 7
norm_layer_wide = tf.keras.layers.Normalization()
norm_layer_deep = tf.keras.layers.Normalization()
norm_wide = norm_layer_wide(input_wide)
norm_deep = norm_layer_deep(input_deep)
hidden1 = tf.keras.layers.Dense(30, activation="relu")(norm_deep)
hidden2 = tf.keras.layers.Dense(30, activation="relu")(hidden1)
concat = tf.keras.layers.concatenate([norm_wide, hidden2])
output = tf.keras.layers.Dense(1)(concat)
aux_output = tf.keras.layers.Dense(1)(hidden2)
model = tf.keras.Model(inputs=[input_wide, input_deep],
                       outputs=[output, aux_output])

# %% [markdown]
# Now we compile model and specify the different loss functions.

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss=("mse", "mse"), loss_weights=(0.9, 0.1), optimizer=optimizer,
              metrics=["RootMeanSquaredError"])

# %% [markdown]
# Now, training, being sure to specify the output labels for both output layers.

# %%
# Remember to adapt the normalization layers!!!
norm_layer_wide.adapt(X_train_wide)
norm_layer_deep.adapt(X_train_deep)
history = model.fit(
    (X_train_wide, X_train_deep), (y_train, y_train), epochs=20,
    validation_data=((X_valid_wide, X_valid_deep), (y_valid, y_valid))
)
# Out:
# Epoch 1/20
# 363/363 [==============================] - 1s 2ms/step - loss: 1.5081 - dense_2_loss: 1.4252 - dense_3_loss: 2.2536 - dense_2_root_mean_squared_error: 1.1938 - dense_3_root_mean_squared_error: 1.5012 - val_loss: 2.4920 - val_dense_2_loss: 1.1147 - val_dense_3_loss: 14.8881 - val_dense_2_root_mean_squared_error: 1.0558 - val_dense_3_root_mean_squared_error: 3.8585
# Epoch 2/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.5528 - dense_2_loss: 0.4963 - dense_3_loss: 1.0614 - dense_2_root_mean_squared_error: 0.7045 - dense_3_root_mean_squared_error: 1.0302 - val_loss: 1.9682 - val_dense_2_loss: 1.3367 - val_dense_3_loss: 7.6514 - val_dense_2_root_mean_squared_error: 1.1562 - val_dense_3_root_mean_squared_error: 2.7661
# Epoch 3/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4824 - dense_2_loss: 0.4515 - dense_3_loss: 0.7608 - dense_2_root_mean_squared_error: 0.6719 - dense_3_root_mean_squared_error: 0.8722 - val_loss: 0.6028 - val_dense_2_loss: 0.4125 - val_dense_3_loss: 2.3155 - val_dense_2_root_mean_squared_error: 0.6422 - val_dense_3_root_mean_squared_error: 1.5217
# Epoch 4/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4410 - dense_2_loss: 0.4200 - dense_3_loss: 0.6307 - dense_2_root_mean_squared_error: 0.6480 - dense_3_root_mean_squared_error: 0.7941 - val_loss: 0.5459 - val_dense_2_loss: 0.5202 - val_dense_3_loss: 0.7770 - val_dense_2_root_mean_squared_error: 0.7213 - val_dense_3_root_mean_squared_error: 0.8815
# Epoch 5/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4235 - dense_2_loss: 0.4072 - dense_3_loss: 0.5705 - dense_2_root_mean_squared_error: 0.6381 - dense_3_root_mean_squared_error: 0.7553 - val_loss: 0.6779 - val_dense_2_loss: 0.6888 - val_dense_3_loss: 0.5796 - val_dense_2_root_mean_squared_error: 0.8299 - val_dense_3_root_mean_squared_error: 0.7613
# Epoch 6/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4127 - dense_2_loss: 0.3980 - dense_3_loss: 0.5453 - dense_2_root_mean_squared_error: 0.6309 - dense_3_root_mean_squared_error: 0.7385 - val_loss: 2.1772 - val_dense_2_loss: 2.2544 - val_dense_3_loss: 1.4818 - val_dense_2_root_mean_squared_error: 1.5015 - val_dense_3_root_mean_squared_error: 1.2173
# Epoch 7/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4180 - dense_2_loss: 0.4050 - dense_3_loss: 0.5354 - dense_2_root_mean_squared_error: 0.6364 - dense_3_root_mean_squared_error: 0.7317 - val_loss: 1.9374 - val_dense_2_loss: 2.0788 - val_dense_3_loss: 0.6645 - val_dense_2_root_mean_squared_error: 1.4418 - val_dense_3_root_mean_squared_error: 0.8152
# Epoch 8/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3962 - dense_2_loss: 0.3830 - dense_3_loss: 0.5151 - dense_2_root_mean_squared_error: 0.6188 - dense_3_root_mean_squared_error: 0.7177 - val_loss: 6.1071 - val_dense_2_loss: 6.7104 - val_dense_3_loss: 0.6776 - val_dense_2_root_mean_squared_error: 2.5904 - val_dense_3_root_mean_squared_error: 0.8231
# Epoch 9/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4001 - dense_2_loss: 0.3890 - dense_3_loss: 0.5006 - dense_2_root_mean_squared_error: 0.6237 - dense_3_root_mean_squared_error: 0.7075 - val_loss: 5.7630 - val_dense_2_loss: 6.2787 - val_dense_3_loss: 1.1219 - val_dense_2_root_mean_squared_error: 2.5057 - val_dense_3_root_mean_squared_error: 1.0592
# Epoch 10/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4363 - dense_2_loss: 0.4296 - dense_3_loss: 0.4971 - dense_2_root_mean_squared_error: 0.6554 - dense_3_root_mean_squared_error: 0.7051 - val_loss: 6.0034 - val_dense_2_loss: 6.4129 - val_dense_3_loss: 2.3177 - val_dense_2_root_mean_squared_error: 2.5324 - val_dense_3_root_mean_squared_error: 1.5224
# Epoch 11/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4051 - dense_2_loss: 0.3970 - dense_3_loss: 0.4785 - dense_2_root_mean_squared_error: 0.6301 - dense_3_root_mean_squared_error: 0.6917 - val_loss: 0.5650 - val_dense_2_loss: 0.5717 - val_dense_3_loss: 0.5050 - val_dense_2_root_mean_squared_error: 0.7561 - val_dense_3_root_mean_squared_error: 0.7106
# Epoch 12/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3955 - dense_2_loss: 0.3870 - dense_3_loss: 0.4720 - dense_2_root_mean_squared_error: 0.6221 - dense_3_root_mean_squared_error: 0.6870 - val_loss: 0.9579 - val_dense_2_loss: 0.9703 - val_dense_3_loss: 0.8464 - val_dense_2_root_mean_squared_error: 0.9850 - val_dense_3_root_mean_squared_error: 0.9200
# Epoch 13/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3674 - dense_2_loss: 0.3577 - dense_3_loss: 0.4550 - dense_2_root_mean_squared_error: 0.5981 - dense_3_root_mean_squared_error: 0.6745 - val_loss: 0.4342 - val_dense_2_loss: 0.4346 - val_dense_3_loss: 0.4301 - val_dense_2_root_mean_squared_error: 0.6593 - val_dense_3_root_mean_squared_error: 0.6558
# Epoch 14/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3597 - dense_2_loss: 0.3502 - dense_3_loss: 0.4458 - dense_2_root_mean_squared_error: 0.5918 - dense_3_root_mean_squared_error: 0.6677 - val_loss: 0.4828 - val_dense_2_loss: 0.4661 - val_dense_3_loss: 0.6329 - val_dense_2_root_mean_squared_error: 0.6827 - val_dense_3_root_mean_squared_error: 0.7956
# Epoch 15/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3553 - dense_2_loss: 0.3464 - dense_3_loss: 0.4357 - dense_2_root_mean_squared_error: 0.5886 - dense_3_root_mean_squared_error: 0.6601 - val_loss: 0.4165 - val_dense_2_loss: 0.4142 - val_dense_3_loss: 0.4374 - val_dense_2_root_mean_squared_error: 0.6436 - val_dense_3_root_mean_squared_error: 0.6614
# Epoch 16/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3517 - dense_2_loss: 0.3431 - dense_3_loss: 0.4292 - dense_2_root_mean_squared_error: 0.5858 - dense_3_root_mean_squared_error: 0.6552 - val_loss: 0.6209 - val_dense_2_loss: 0.6033 - val_dense_3_loss: 0.7792 - val_dense_2_root_mean_squared_error: 0.7767 - val_dense_3_root_mean_squared_error: 0.8827
# Epoch 17/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3516 - dense_2_loss: 0.3433 - dense_3_loss: 0.4264 - dense_2_root_mean_squared_error: 0.5859 - dense_3_root_mean_squared_error: 0.6530 - val_loss: 0.5168 - val_dense_2_loss: 0.5261 - val_dense_3_loss: 0.4332 - val_dense_2_root_mean_squared_error: 0.7253 - val_dense_3_root_mean_squared_error: 0.6582
# Epoch 18/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3467 - dense_2_loss: 0.3387 - dense_3_loss: 0.4186 - dense_2_root_mean_squared_error: 0.5820 - dense_3_root_mean_squared_error: 0.6470 - val_loss: 3.2528 - val_dense_2_loss: 3.3828 - val_dense_3_loss: 2.0828 - val_dense_2_root_mean_squared_error: 1.8392 - val_dense_3_root_mean_squared_error: 1.4432
# Epoch 19/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3645 - dense_2_loss: 0.3574 - dense_3_loss: 0.4282 - dense_2_root_mean_squared_error: 0.5978 - dense_3_root_mean_squared_error: 0.6544 - val_loss: 3.4808 - val_dense_2_loss: 3.7579 - val_dense_3_loss: 0.9873 - val_dense_2_root_mean_squared_error: 1.9385 - val_dense_3_root_mean_squared_error: 0.9936
# Epoch 20/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3737 - dense_2_loss: 0.3687 - dense_3_loss: 0.4189 - dense_2_root_mean_squared_error: 0.6072 - dense_3_root_mean_squared_error: 0.6472 - val_loss: 1.5125 - val_dense_2_loss: 1.2435 - val_dense_3_loss: 3.9335 - val_dense_2_root_mean_squared_error: 1.1151 - val_dense_3_root_mean_squared_error: 1.9833

# %%
eval_results = model.evaluate((X_test_wide, X_test_deep), (y_test, y_test))
weighted_sum_of_losses, main_loss, aux_loss, main_rmse, aux_rmse = eval_results
print(f"""
Weighed Sum of Losses: {weighted_sum_of_losses}
Main Loss: {main_loss}
Aux Loss: {aux_loss}
Main RMSE: {main_rmse}
Aux RMSE: {aux_rmse}
      """)
# Out:
#  54/162 [=========>....................] - ETA: 0s - loss: 0.3701 - dense_2_loss: 0.3611 - dense_3_loss: 0.4510 - dense_2_root_mean_squared_error: 0.6009 - dense_3_root_mean_squared_error: 0.6716
# 162/162 [==============================] - 0s 983us/step - loss: 0.3458 - dense_2_loss: 0.3369 - dense_3_loss: 0.4264 - dense_2_root_mean_squared_error: 0.5804 - dense_3_root_mean_squared_error: 0.6530
#
# Weighed Sum of Losses: 0.3458431661128998
# Main Loss: 0.3368906080722809
# Aux Loss: 0.4264164865016937
# Main RMSE: 0.5804227590560913
# Aux RMSE: 0.6530057191848755

# %%
import matplotlib.pyplot as plt
import pandas as pd

pd.DataFrame(history.history).plot(
    figsize=(8, 5), xlim=[0, 20], ylim=[0, 2], grid=True, xlabel="Epoch",
    style=["r--", "r--.", "b-", "b-*"])
plt.legend(loc="lower left")  # extra code
plt.show()

# %% [markdown]
# Note that this appears to have substantially improved things for the validation set, indicating that we indeed seem to be generalizing our data quite a bit better!

# %% [markdown]
# ## Additional Software Features
#
# Keras provides several additional software features that can be used to make the process of working with networks more useful.
#
# #### The Subclassing API
#
# The Subclassing API allows you to define custom models by subclassing the `tf.keras.Model` class. In this approach, you create a new class that inherits from `tf.keras.Model` and defines your own forward pass for the model. This method provides the greatest flexibility in defining models, as you can add loops, conditional branches, and even custom layers directly within your model.
#
# #### Why Use the Subclassing API?
#
# 1. **Custom Behavior:**
#    - If you need a model that does not fit the standard sequential or functional paradigms, subclassing enables you to implement custom behavior in the forward pass.
#
# 2. **Research and Experimentation:**
#    - For researchers experimenting with new ideas, subclassing offers a way to express complex models or layers in an intuitive manner.
#
# 3. **Dynamic Models:**
#    - Subclassing is particularly suited for dynamic models, where the architecture can change based on the input data, something that's harder to achieve with the Sequential and Functional APIs.
#
# #### How to Implement a Model using Subclassing?
#
# 1. **Define a Model Class:**
#    - Create a new class that inherits from `tf.keras.Model`.
#    - Define the layers in the `__init__` method.
#    - Implement the model's forward pass in the `call` method.
#
# 2. **Instantiate and Use the Model:**
#    - Like other Keras models, you compile and train it using `.compile()` and `.fit()` methods.
#    - It can be used for prediction with `.predict()`.
#
# #### Key Points
#
# - **Debugging:** Subclassing can make debugging easier since it works just like regular Python code.
# - **Complexity:** It's slightly more complex and error-prone than using Sequential or Functional APIs due to the lack of model validation before training.
# - **Serialization:** Subclassed models have limitations in terms of saving and loading. The structure of the model is not explicitly defined, so when saving the model, Keras saves the model's weights only.

# %%
class WideAndDeepModel(tf.keras.Model):
    def __init__(self, units=30, activation="relu", **kwargs):
        super().__init__(**kwargs)  # needed to support naming the model
        self.norm_layer_wide = tf.keras.layers.Normalization()
        self.norm_layer_deep = tf.keras.layers.Normalization()
        self.hidden1 = tf.keras.layers.Dense(units, activation=activation)
        self.hidden2 = tf.keras.layers.Dense(units, activation=activation)
        self.main_output = tf.keras.layers.Dense(1)
        self.aux_output = tf.keras.layers.Dense(1)
        
    def call(self, inputs):
        input_wide, input_deep = inputs
        norm_wide = self.norm_layer_wide(input_wide)
        norm_deep = self.norm_layer_deep(input_deep)
        hidden1 = self.hidden1(norm_deep)
        hidden2 = self.hidden2(hidden1)
        concat = tf.keras.layers.concatenate([norm_wide, hidden2])
        output = self.main_output(concat)
        aux_output = self.aux_output(hidden2)
        return output, aux_output

tf.random.set_seed(42)  # extra code – just for reproducibility
model = WideAndDeepModel(30, activation="relu", name="my_cool_model")

# %% [markdown]
# Now, to instantiate and train:

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)  # extra code – just for reproducibility
model = WideAndDeepModel(30, activation="relu", name="my_cool_model")
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="mse", loss_weights=[0.9, 0.1], optimizer=optimizer,
              metrics=["RootMeanSquaredError"])
model.norm_layer_wide.adapt(X_train_wide)
model.norm_layer_deep.adapt(X_train_deep)
history = model.fit(
    (X_train_wide, X_train_deep), (y_train, y_train), epochs=10,
    validation_data=((X_valid_wide, X_valid_deep), (y_valid, y_valid)))
eval_results = model.evaluate((X_test_wide, X_test_deep), (y_test, y_test))
weighted_sum_of_losses, main_loss, aux_loss, main_rmse, aux_rmse = eval_results
y_pred_main, y_pred_aux = model.predict((X_new_wide, X_new_deep))
# Out:
# Epoch 1/10
# 363/363 [==============================] - 1s 2ms/step - loss: 1.8208 - output_1_loss: 1.7160 - output_2_loss: 2.7642 - output_1_root_mean_squared_error: 1.3099 - output_2_root_mean_squared_error: 1.6626 - val_loss: 8.0155 - val_output_1_loss: 6.8895 - val_output_2_loss: 18.1492 - val_output_1_root_mean_squared_error: 2.6248 - val_output_2_root_mean_squared_error: 4.2602
# Epoch 2/10
# 363/363 [==============================] - 1s 2ms/step - loss: 0.6417 - output_1_loss: 0.6030 - output_2_loss: 0.9896 - output_1_root_mean_squared_error: 0.7765 - output_2_root_mean_squared_error: 0.9948 - val_loss: 4.0724 - val_output_1_loss: 3.2805 - val_output_2_loss: 11.1988 - val_output_1_root_mean_squared_error: 1.8112 - val_output_2_root_mean_squared_error: 3.3465
# Epoch 3/10
# 363/363 [==============================] - 1s 1ms/step - loss: 0.5149 - output_1_loss: 0.4947 - output_2_loss: 0.6972 - output_1_root_mean_squared_error: 0.7033 - output_2_root_mean_squared_error: 0.8350 - val_loss: 1.0816 - val_output_1_loss: 0.7298 - val_output_2_loss: 4.2473 - val_output_1_root_mean_squared_error: 0.8543 - val_output_2_root_mean_squared_error: 2.0609
# Epoch 4/10
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4454 - output_1_loss: 0.4309 - output_2_loss: 0.5768 - output_1_root_mean_squared_error: 0.6564 - output_2_root_mean_squared_error: 0.7595 - val_loss: 0.5366 - val_output_1_loss: 0.3977 - val_output_2_loss: 1.7872 - val_output_1_root_mean_squared_error: 0.6306 - val_output_2_root_mean_squared_error: 1.3368
# Epoch 5/10
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4121 - output_1_loss: 0.3991 - output_2_loss: 0.5292 - output_1_root_mean_squared_error: 0.6317 - output_2_root_mean_squared_error: 0.7275 - val_loss: 0.4601 - val_output_1_loss: 0.4101 - val_output_2_loss: 0.9099 - val_output_1_root_mean_squared_error: 0.6404 - val_output_2_root_mean_squared_error: 0.9539
# Epoch 6/10
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3914 - output_1_loss: 0.3803 - output_2_loss: 0.4909 - output_1_root_mean_squared_error: 0.6167 - output_2_root_mean_squared_error: 0.7007 - val_loss: 0.5627 - val_output_1_loss: 0.5145 - val_output_2_loss: 0.9969 - val_output_1_root_mean_squared_error: 0.7173 - val_output_2_root_mean_squared_error: 0.9985
# Epoch 7/10
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3806 - output_1_loss: 0.3701 - output_2_loss: 0.4752 - output_1_root_mean_squared_error: 0.6084 - output_2_root_mean_squared_error: 0.6893 - val_loss: 0.4702 - val_output_1_loss: 0.4718 - val_output_2_loss: 0.4561 - val_output_1_root_mean_squared_error: 0.6869 - val_output_2_root_mean_squared_error: 0.6753
# Epoch 8/10
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3692 - output_1_loss: 0.3598 - output_2_loss: 0.4537 - output_1_root_mean_squared_error: 0.5999 - output_2_root_mean_squared_error: 0.6736 - val_loss: 0.7416 - val_output_1_loss: 0.7368 - val_output_2_loss: 0.7842 - val_output_1_root_mean_squared_error: 0.8584 - val_output_2_root_mean_squared_error: 0.8856
# Epoch 9/10
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3633 - output_1_loss: 0.3540 - output_2_loss: 0.4463 - output_1_root_mean_squared_error: 0.5950 - output_2_root_mean_squared_error: 0.6681 - val_loss: 0.5038 - val_output_1_loss: 0.5110 - val_output_2_loss: 0.4383 - val_output_1_root_mean_squared_error: 0.7149 - val_output_2_root_mean_squared_error: 0.6620
# Epoch 10/10
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3604 - output_1_loss: 0.3523 - output_2_loss: 0.4334 - output_1_root_mean_squared_error: 0.5936 - output_2_root_mean_squared_error: 0.6584 - val_loss: 1.0719 - val_output_1_loss: 1.0769 - val_output_2_loss: 1.0274 - val_output_1_root_mean_squared_error: 1.0377 - val_output_2_root_mean_squared_error: 1.0136
# 162/162 [==============================] - 0s 973us/step - loss: 0.3559 - output_1_loss: 0.3477 - output_2_loss: 0.4297 - output_1_root_mean_squared_error: 0.5897 - output_2_root_mean_squared_error: 0.6555
# 1/1 [==============================] - 0s 48ms/step

# %% [markdown]
# ## Saving and restoring models

# %% [markdown]
# Models can be easily saved off for future use with:

# %%
model.save("my_keras_model", save_format="tf")
# Out:
# INFO:tensorflow:Assets written to: my_keras_model/assets
# INFO:tensorflow:Assets written to: my_keras_model/assets

# %% [markdown]
# All aspects of the model are saved this way, including weights and any hyperparameters.  Loading the model can be easily accomplished with:

# %%
model = tf.keras.models.load_model("my_keras_model")

# %% [markdown]
# You can also save and load just the weights for a network, which is faster uses less disk space then storing the entire model.  This is useful when saving "checkpoints" during the model training process.  Checkpoints provide a restore point if something goes awry during the training process.  To accomplish this, we use callbacks, described below.

# %% [markdown]
# ### Using Callbacks
#
# Sometimes it is useful to interrupt the training process to inspect aspects of the network. The `fit()` methods accepts a set of functions (referred to as callbacks) which can be run during the training process.  There are three places when you can run callback functions:
# - Before and after training
# - Before and after each epoch
# - Before and after each batch
#
# Keras offers a number of [pre-built callbacks](https://keras.io/api/callbacks/) and you [can write your own](https://keras.io/guides/writing_your_own_callbacks/) if you want.
#
# #### Examples
#
# **Model Checkpoints**
#
# The ModelCheckpoint callback allows you to save checkpoints at regular intervals during training.  This can be useful both for inspection, and as a backup mechanism in case something goes wrong during training. This is also a nice way to avoid overtraining with too many epochs, since it is easy to roll back to a previous training state.
#
# ~~~python
# checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("my_checkpoints", save_weights_only=True)
# history = model.fit([...], callbacks=[checkpoint_cb])
# ~~~
#
# **Early Stopping**
#
# The `EarlyStopping` callback allows you to interrupt training when no progress is made on the validation step for a number of epochs.  Setting `restore_best_weights=True` will roll back to the best model at the end of training.
#
# ~~~python
# early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,restore_best_weights=True)
# history = model.fit([...], callbacks=[checkpoint_cb, early_stopping_cb])
# ~~~

# %% [markdown]
# ### Using Tensorboard
#
# Tensorflow provides a UI called Tensorboard for inspecting the performance of training.  To use Tensorboard, we need to log data in a special format using the Tensorboard callback.  Generally, speaking, it's useful to organize log data with a single top level directory for all logging (you might want to add this to your `.gitignore` file) and then create logs for different runs in subdirectories.  The following code takes care of creating the path where logs should reside.

# %%
from pathlib import Path 
from time import strftime
def get_run_logdir(root_logdir="./logs"):
    return Path(root_logdir) / strftime("run_%Y_%m_%d_%H_%M_%S")


get_run_logdir()
# Out:
# PosixPath('logs/run_2023_11_27_20_15_00')

# %% [markdown]
# To use Tensorboard, all we need is to install the callback when we train the model.  First, set up the model (we'll use the subclassed version above):

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)  # extra code – just for reproducibility
model = WideAndDeepModel(30, activation="relu", name="my_cool_model")
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="mse", loss_weights=[0.9, 0.1], optimizer=optimizer,
              metrics=["RootMeanSquaredError"])
model.norm_layer_wide.adapt(X_train_wide)
model.norm_layer_deep.adapt(X_train_deep)

# %% [markdown]
# Then, we'll add the tensorboard callback and train.

# %%
test_dir = get_run_logdir()
tensorboard_cb = tf.keras.callbacks.TensorBoard(test_dir, profile_batch=(100, 200))
history=model.fit(
    (X_train_wide, X_train_deep), (y_train, y_train), epochs=20,
    validation_data=((X_valid_wide, X_valid_deep), (y_valid, y_valid)),callbacks=[tensorboard_cb])
# Out:
# Epoch 1/20
# 2023-11-27 20:15:12.801825: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:104] Profiler session initializing.
# 2023-11-27 20:15:12.802107: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:119] Profiler session started.
# 2023-11-27 20:15:12.802407: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:131] Profiler session tear down.
# 200/363 [===============>..............] - ETA: 0s - loss: 2.4463 - output_1_loss: 2.3907 - output_2_loss: 2.9463 - output_1_root_mean_squared_error: 1.5462 - output_2_root_mean_squared_error: 1.7165
# 2023-11-27 20:15:13.654239: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:104] Profiler session initializing.
# 2023-11-27 20:15:13.654280: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:119] Profiler session started.
# 2023-11-27 20:15:13.810217: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:70] Profiler session collecting data.
# 2023-11-27 20:15:13.821570: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:131] Profiler session tear down.
# 2023-11-27 20:15:13.822298: I external/local_tsl/tsl/profiler/rpc/client/save_profile.cc:144] Collecting XSpace to repository: logs/run_2023_11_27_20_15_12/plugins/profile/2023_11_27_20_15_13/codespaces-7e1c9e.xplane.pb
# 363/363 [==============================] - 2s 2ms/step - loss: 1.7831 - output_1_loss: 1.7451 - output_2_loss: 2.1258 - output_1_root_mean_squared_error: 1.3210 - output_2_root_mean_squared_error: 1.4580 - val_loss: 0.9624 - val_output_1_loss: 0.8482 - val_output_2_loss: 1.9895 - val_output_1_root_mean_squared_error: 0.9210 - val_output_2_root_mean_squared_error: 1.4105
# Epoch 2/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.6508 - output_1_loss: 0.6428 - output_2_loss: 0.7231 - output_1_root_mean_squared_error: 0.8017 - output_2_root_mean_squared_error: 0.8503 - val_loss: 1.4152 - val_output_1_loss: 1.4556 - val_output_2_loss: 1.0516 - val_output_1_root_mean_squared_error: 1.2065 - val_output_2_root_mean_squared_error: 1.0255
# Epoch 3/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.5363 - output_1_loss: 0.5307 - output_2_loss: 0.5866 - output_1_root_mean_squared_error: 0.7285 - output_2_root_mean_squared_error: 0.7659 - val_loss: 0.5153 - val_output_1_loss: 0.4888 - val_output_2_loss: 0.7537 - val_output_1_root_mean_squared_error: 0.6992 - val_output_2_root_mean_squared_error: 0.8681
# Epoch 4/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4692 - output_1_loss: 0.4604 - output_2_loss: 0.5489 - output_1_root_mean_squared_error: 0.6785 - output_2_root_mean_squared_error: 0.7409 - val_loss: 0.4362 - val_output_1_loss: 0.4094 - val_output_2_loss: 0.6770 - val_output_1_root_mean_squared_error: 0.6398 - val_output_2_root_mean_squared_error: 0.8228
# Epoch 5/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4253 - output_1_loss: 0.4152 - output_2_loss: 0.5162 - output_1_root_mean_squared_error: 0.6443 - output_2_root_mean_squared_error: 0.7185 - val_loss: 0.3929 - val_output_1_loss: 0.3724 - val_output_2_loss: 0.5779 - val_output_1_root_mean_squared_error: 0.6102 - val_output_2_root_mean_squared_error: 0.7602
# Epoch 6/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3939 - output_1_loss: 0.3840 - output_2_loss: 0.4833 - output_1_root_mean_squared_error: 0.6196 - output_2_root_mean_squared_error: 0.6952 - val_loss: 0.5258 - val_output_1_loss: 0.5107 - val_output_2_loss: 0.6616 - val_output_1_root_mean_squared_error: 0.7146 - val_output_2_root_mean_squared_error: 0.8134
# Epoch 7/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3764 - output_1_loss: 0.3672 - output_2_loss: 0.4589 - output_1_root_mean_squared_error: 0.6060 - output_2_root_mean_squared_error: 0.6774 - val_loss: 0.3538 - val_output_1_loss: 0.3430 - val_output_2_loss: 0.4509 - val_output_1_root_mean_squared_error: 0.5856 - val_output_2_root_mean_squared_error: 0.6715
# Epoch 8/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3634 - output_1_loss: 0.3549 - output_2_loss: 0.4394 - output_1_root_mean_squared_error: 0.5957 - output_2_root_mean_squared_error: 0.6629 - val_loss: 0.5013 - val_output_1_loss: 0.5003 - val_output_2_loss: 0.5102 - val_output_1_root_mean_squared_error: 0.7073 - val_output_2_root_mean_squared_error: 0.7143
# Epoch 9/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3563 - output_1_loss: 0.3485 - output_2_loss: 0.4265 - output_1_root_mean_squared_error: 0.5903 - output_2_root_mean_squared_error: 0.6530 - val_loss: 0.3555 - val_output_1_loss: 0.3484 - val_output_2_loss: 0.4192 - val_output_1_root_mean_squared_error: 0.5903 - val_output_2_root_mean_squared_error: 0.6475
# Epoch 10/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3537 - output_1_loss: 0.3467 - output_2_loss: 0.4170 - output_1_root_mean_squared_error: 0.5888 - output_2_root_mean_squared_error: 0.6458 - val_loss: 0.9396 - val_output_1_loss: 0.9569 - val_output_2_loss: 0.7845 - val_output_1_root_mean_squared_error: 0.9782 - val_output_2_root_mean_squared_error: 0.8857
# Epoch 11/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3477 - output_1_loss: 0.3407 - output_2_loss: 0.4106 - output_1_root_mean_squared_error: 0.5837 - output_2_root_mean_squared_error: 0.6408 - val_loss: 0.4036 - val_output_1_loss: 0.4042 - val_output_2_loss: 0.3982 - val_output_1_root_mean_squared_error: 0.6358 - val_output_2_root_mean_squared_error: 0.6310
# Epoch 12/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3546 - output_1_loss: 0.3485 - output_2_loss: 0.4097 - output_1_root_mean_squared_error: 0.5903 - output_2_root_mean_squared_error: 0.6401 - val_loss: 1.2766 - val_output_1_loss: 1.3551 - val_output_2_loss: 0.5706 - val_output_1_root_mean_squared_error: 1.1641 - val_output_2_root_mean_squared_error: 0.7554
# Epoch 13/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3468 - output_1_loss: 0.3402 - output_2_loss: 0.4055 - output_1_root_mean_squared_error: 0.5833 - output_2_root_mean_squared_error: 0.6368 - val_loss: 0.3435 - val_output_1_loss: 0.3362 - val_output_2_loss: 0.4090 - val_output_1_root_mean_squared_error: 0.5799 - val_output_2_root_mean_squared_error: 0.6396
# Epoch 14/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3409 - output_1_loss: 0.3342 - output_2_loss: 0.4012 - output_1_root_mean_squared_error: 0.5781 - output_2_root_mean_squared_error: 0.6334 - val_loss: 0.6218 - val_output_1_loss: 0.6405 - val_output_2_loss: 0.4543 - val_output_1_root_mean_squared_error: 0.8003 - val_output_2_root_mean_squared_error: 0.6740
# Epoch 15/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3388 - output_1_loss: 0.3324 - output_2_loss: 0.3961 - output_1_root_mean_squared_error: 0.5766 - output_2_root_mean_squared_error: 0.6294 - val_loss: 0.4187 - val_output_1_loss: 0.4213 - val_output_2_loss: 0.3953 - val_output_1_root_mean_squared_error: 0.6491 - val_output_2_root_mean_squared_error: 0.6287
# Epoch 16/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3356 - output_1_loss: 0.3291 - output_2_loss: 0.3942 - output_1_root_mean_squared_error: 0.5737 - output_2_root_mean_squared_error: 0.6278 - val_loss: 0.8300 - val_output_1_loss: 0.8531 - val_output_2_loss: 0.6217 - val_output_1_root_mean_squared_error: 0.9236 - val_output_2_root_mean_squared_error: 0.7885
# Epoch 17/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3376 - output_1_loss: 0.3313 - output_2_loss: 0.3942 - output_1_root_mean_squared_error: 0.5756 - output_2_root_mean_squared_error: 0.6278 - val_loss: 0.4602 - val_output_1_loss: 0.4687 - val_output_2_loss: 0.3838 - val_output_1_root_mean_squared_error: 0.6846 - val_output_2_root_mean_squared_error: 0.6195
# Epoch 18/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3324 - output_1_loss: 0.3262 - output_2_loss: 0.3883 - output_1_root_mean_squared_error: 0.5712 - output_2_root_mean_squared_error: 0.6231 - val_loss: 2.0146 - val_output_1_loss: 2.1279 - val_output_2_loss: 0.9950 - val_output_1_root_mean_squared_error: 1.4587 - val_output_2_root_mean_squared_error: 0.9975
# Epoch 19/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3383 - output_1_loss: 0.3326 - output_2_loss: 0.3897 - output_1_root_mean_squared_error: 0.5767 - output_2_root_mean_squared_error: 0.6242 - val_loss: 0.9125 - val_output_1_loss: 0.9689 - val_output_2_loss: 0.4053 - val_output_1_root_mean_squared_error: 0.9843 - val_output_2_root_mean_squared_error: 0.6366
# Epoch 20/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3377 - output_1_loss: 0.3324 - output_2_loss: 0.3863 - output_1_root_mean_squared_error: 0.5765 - output_2_root_mean_squared_error: 0.6215 - val_loss: 0.9326 - val_output_1_loss: 0.9572 - val_output_2_loss: 0.7115 - val_output_1_root_mean_squared_error: 0.9784 - val_output_2_root_mean_squared_error: 0.8435

# %% [markdown]
# Now, for comparison's sake, we'll run the model again with a slightly higher learning rate.

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)  # extra code – just for reproducibility
model = WideAndDeepModel(30, activation="relu", name="my_cool_model")

# Doubled the learning
optimizer = tf.keras.optimizers.Adam(learning_rate=2e-3)
model.compile(loss="mse", loss_weights=[0.9, 0.1], optimizer=optimizer,
              metrics=["RootMeanSquaredError"])
model.norm_layer_wide.adapt(X_train_wide)
model.norm_layer_deep.adapt(X_train_deep)

# %%
test_dir = get_run_logdir()
tensorboard_cb = tf.keras.callbacks.TensorBoard(test_dir, profile_batch=(100, 200))
history=model.fit(
    (X_train_wide, X_train_deep), (y_train, y_train), epochs=20,
    validation_data=((X_valid_wide, X_valid_deep), (y_valid, y_valid)),callbacks=[tensorboard_cb])
# Out:
# Epoch 1/20
# 2023-11-26 15:22:29.855289: I tensorflow/tsl/profiler/lib/profiler_session.cc:104] Profiler session initializing.
# 2023-11-26 15:22:29.855301: I tensorflow/tsl/profiler/lib/profiler_session.cc:119] Profiler session started.
# 2023-11-26 15:22:29.855596: I tensorflow/tsl/profiler/lib/profiler_session.cc:131] Profiler session tear down.
# 164/363 [============>.................] - ETA: 0s - loss: 1.4607 - output_1_loss: 1.3658 - output_2_loss: 2.3145 - output_1_root_mean_squared_error: 1.1687 - output_2_root_mean_squared_error: 1.5214
# 2023-11-26 15:22:31.537607: I tensorflow/tsl/profiler/lib/profiler_session.cc:104] Profiler session initializing.
# 2023-11-26 15:22:31.537629: I tensorflow/tsl/profiler/lib/profiler_session.cc:119] Profiler session started.
# 200/363 [===============>..............] - ETA: 0s - loss: 1.2960 - output_1_loss: 1.2131 - output_2_loss: 2.0416 - output_1_root_mean_squared_error: 1.1014 - output_2_root_mean_squared_error: 1.4288
# 2023-11-26 15:22:31.821895: I tensorflow/tsl/profiler/lib/profiler_session.cc:70] Profiler session collecting data.
# 2023-11-26 15:22:31.956079: I tensorflow/tsl/profiler/lib/profiler_session.cc:131] Profiler session tear down.
# 2023-11-26 15:22:31.957272: I tensorflow/tsl/profiler/rpc/client/save_profile.cc:144] Collecting XSpace to repository: logs/run_2023_11_26_15_22_29/plugins/profile/2023_11_26_15_22_31/IST-326-3707.xplane.pb
# 363/363 [==============================] - 3s 4ms/step - loss: 0.9676 - output_1_loss: 0.9161 - output_2_loss: 1.4313 - output_1_root_mean_squared_error: 0.9571 - output_2_root_mean_squared_error: 1.1964 - val_loss: 0.6387 - val_output_1_loss: 0.5144 - val_output_2_loss: 1.7567 - val_output_1_root_mean_squared_error: 0.7172 - val_output_2_root_mean_squared_error: 1.3254
# Epoch 2/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4449 - output_1_loss: 0.4285 - output_2_loss: 0.5921 - output_1_root_mean_squared_error: 0.6546 - output_2_root_mean_squared_error: 0.7695 - val_loss: 0.6267 - val_output_1_loss: 0.5586 - val_output_2_loss: 1.2394 - val_output_1_root_mean_squared_error: 0.7474 - val_output_2_root_mean_squared_error: 1.1133
# Epoch 3/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4351 - output_1_loss: 0.4209 - output_2_loss: 0.5624 - output_1_root_mean_squared_error: 0.6488 - output_2_root_mean_squared_error: 0.7500 - val_loss: 0.4165 - val_output_1_loss: 0.3993 - val_output_2_loss: 0.5711 - val_output_1_root_mean_squared_error: 0.6319 - val_output_2_root_mean_squared_error: 0.7557
# Epoch 4/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4067 - output_1_loss: 0.3934 - output_2_loss: 0.5259 - output_1_root_mean_squared_error: 0.6272 - output_2_root_mean_squared_error: 0.7252 - val_loss: 0.9187 - val_output_1_loss: 0.7923 - val_output_2_loss: 2.0557 - val_output_1_root_mean_squared_error: 0.8901 - val_output_2_root_mean_squared_error: 1.4338
# Epoch 5/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4005 - output_1_loss: 0.3892 - output_2_loss: 0.5019 - output_1_root_mean_squared_error: 0.6239 - output_2_root_mean_squared_error: 0.7084 - val_loss: 0.7226 - val_output_1_loss: 0.7470 - val_output_2_loss: 0.5033 - val_output_1_root_mean_squared_error: 0.8643 - val_output_2_root_mean_squared_error: 0.7094
# Epoch 6/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3844 - output_1_loss: 0.3745 - output_2_loss: 0.4739 - output_1_root_mean_squared_error: 0.6120 - output_2_root_mean_squared_error: 0.6884 - val_loss: 0.4845 - val_output_1_loss: 0.3808 - val_output_2_loss: 1.4178 - val_output_1_root_mean_squared_error: 0.6171 - val_output_2_root_mean_squared_error: 1.1907
# Epoch 7/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3778 - output_1_loss: 0.3682 - output_2_loss: 0.4646 - output_1_root_mean_squared_error: 0.6068 - output_2_root_mean_squared_error: 0.6816 - val_loss: 0.3480 - val_output_1_loss: 0.3350 - val_output_2_loss: 0.4655 - val_output_1_root_mean_squared_error: 0.5788 - val_output_2_root_mean_squared_error: 0.6823
# Epoch 8/20
# 363/363 [==============================] - 1s 4ms/step - loss: 0.3657 - output_1_loss: 0.3577 - output_2_loss: 0.4379 - output_1_root_mean_squared_error: 0.5981 - output_2_root_mean_squared_error: 0.6618 - val_loss: 1.9119 - val_output_1_loss: 2.0619 - val_output_2_loss: 0.5619 - val_output_1_root_mean_squared_error: 1.4359 - val_output_2_root_mean_squared_error: 0.7496
# Epoch 9/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3623 - output_1_loss: 0.3551 - output_2_loss: 0.4266 - output_1_root_mean_squared_error: 0.5959 - output_2_root_mean_squared_error: 0.6532 - val_loss: 5.1373 - val_output_1_loss: 5.5701 - val_output_2_loss: 1.2415 - val_output_1_root_mean_squared_error: 2.3601 - val_output_2_root_mean_squared_error: 1.1142
# Epoch 10/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4074 - output_1_loss: 0.4043 - output_2_loss: 0.4358 - output_1_root_mean_squared_error: 0.6358 - output_2_root_mean_squared_error: 0.6602 - val_loss: 0.4443 - val_output_1_loss: 0.4204 - val_output_2_loss: 0.6596 - val_output_1_root_mean_squared_error: 0.6484 - val_output_2_root_mean_squared_error: 0.8122
# Epoch 11/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3521 - output_1_loss: 0.3450 - output_2_loss: 0.4160 - output_1_root_mean_squared_error: 0.5874 - output_2_root_mean_squared_error: 0.6449 - val_loss: 0.3696 - val_output_1_loss: 0.3625 - val_output_2_loss: 0.4335 - val_output_1_root_mean_squared_error: 0.6021 - val_output_2_root_mean_squared_error: 0.6584
# Epoch 12/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3528 - output_1_loss: 0.3464 - output_2_loss: 0.4110 - output_1_root_mean_squared_error: 0.5885 - output_2_root_mean_squared_error: 0.6411 - val_loss: 1.2691 - val_output_1_loss: 1.2570 - val_output_2_loss: 1.3787 - val_output_1_root_mean_squared_error: 1.1211 - val_output_2_root_mean_squared_error: 1.1742
# Epoch 13/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3511 - output_1_loss: 0.3448 - output_2_loss: 0.4075 - output_1_root_mean_squared_error: 0.5872 - output_2_root_mean_squared_error: 0.6384 - val_loss: 0.3533 - val_output_1_loss: 0.3156 - val_output_2_loss: 0.6926 - val_output_1_root_mean_squared_error: 0.5618 - val_output_2_root_mean_squared_error: 0.8322
# Epoch 14/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3519 - output_1_loss: 0.3449 - output_2_loss: 0.4143 - output_1_root_mean_squared_error: 0.5873 - output_2_root_mean_squared_error: 0.6437 - val_loss: 1.0282 - val_output_1_loss: 1.0892 - val_output_2_loss: 0.4787 - val_output_1_root_mean_squared_error: 1.0437 - val_output_2_root_mean_squared_error: 0.6919
# Epoch 15/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3478 - output_1_loss: 0.3422 - output_2_loss: 0.3980 - output_1_root_mean_squared_error: 0.5850 - output_2_root_mean_squared_error: 0.6309 - val_loss: 0.3666 - val_output_1_loss: 0.3647 - val_output_2_loss: 0.3831 - val_output_1_root_mean_squared_error: 0.6039 - val_output_2_root_mean_squared_error: 0.6190
# Epoch 16/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3366 - output_1_loss: 0.3306 - output_2_loss: 0.3907 - output_1_root_mean_squared_error: 0.5750 - output_2_root_mean_squared_error: 0.6250 - val_loss: 0.3178 - val_output_1_loss: 0.3092 - val_output_2_loss: 0.3953 - val_output_1_root_mean_squared_error: 0.5560 - val_output_2_root_mean_squared_error: 0.6287
# Epoch 17/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3371 - output_1_loss: 0.3312 - output_2_loss: 0.3905 - output_1_root_mean_squared_error: 0.5755 - output_2_root_mean_squared_error: 0.6249 - val_loss: 0.4598 - val_output_1_loss: 0.4104 - val_output_2_loss: 0.9041 - val_output_1_root_mean_squared_error: 0.6406 - val_output_2_root_mean_squared_error: 0.9508
# Epoch 18/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3315 - output_1_loss: 0.3257 - output_2_loss: 0.3842 - output_1_root_mean_squared_error: 0.5707 - output_2_root_mean_squared_error: 0.6199 - val_loss: 0.3308 - val_output_1_loss: 0.3235 - val_output_2_loss: 0.3957 - val_output_1_root_mean_squared_error: 0.5688 - val_output_2_root_mean_squared_error: 0.6291
# Epoch 19/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3274 - output_1_loss: 0.3219 - output_2_loss: 0.3771 - output_1_root_mean_squared_error: 0.5673 - output_2_root_mean_squared_error: 0.6141 - val_loss: 0.3721 - val_output_1_loss: 0.3666 - val_output_2_loss: 0.4217 - val_output_1_root_mean_squared_error: 0.6054 - val_output_2_root_mean_squared_error: 0.6494
# Epoch 20/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.3409 - output_1_loss: 0.3362 - output_2_loss: 0.3831 - output_1_root_mean_squared_error: 0.5799 - output_2_root_mean_squared_error: 0.6190 - val_loss: 0.3394 - val_output_1_loss: 0.3152 - val_output_2_loss: 0.5574 - val_output_1_root_mean_squared_error: 0.5614 - val_output_2_root_mean_squared_error: 0.7466

# %% [markdown]
# Now we can start up `tensorboard` to have a look at our log files.  Once tensorboard is running, you can browse to http://localhost:6006/ to have a look.

# %%
# %load_ext tensorboard 
# %tensorboard --logdir=./logs

# %% [markdown]
# Tensorboard is a highly functional tool, and has some neat functions for visualizing high dimensional embedding spaces within a network.  You can read more about this ![here](https://www.tensorflow.org/tensorboard/tensorboard_projector_plugin).
